# %%
#Programmer :Omkar Sunil Rahane
#College:Keystone school engineering pune
#Class:TE # Div:B
#Roll no.:26

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diamonds=pd.read_csv('diamond.csv')

# %%
diamonds
# Out:
#       Carat Weight              Cut Color Clarity Polish Symmetry Report  \
# 0             1.10            Ideal     H     SI1     VG       EX    GIA
# 1             0.83            Ideal     H     VS1     ID       ID   AGSL
# 2             0.85            Ideal     H     SI1     EX       EX    GIA
# 3             0.91            Ideal     E     SI1     VG       VG    GIA
# 4             0.83            Ideal     G     SI1     EX       EX    GIA
# ...            ...              ...   ...     ...    ...      ...    ...
# 5995          1.03            Ideal     D     SI1     EX       EX    GIA
# 5996          1.00        Very Good     D     SI1     VG       VG    GIA
# 5997          1.02            Ideal     D     SI1     EX       EX    GIA
# 5998          1.27  Signature-Ideal     G     VS1     EX       EX    GIA
# 5999          2.19            Ideal     E     VS1     EX       EX    GIA
#
#       Price
# 0      5169
# 1      3470
# 2      3183
# 3      4370
# 4      3171
# ...     ...
# 5995   6250
# 5996   5328
# 5997   6157
# 5998  11206
# 5999  30507
#
# [6000 rows x 8 columns]

# %%
diamonds.head(5)
# Out:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report  Price
# 0          1.10  Ideal     H     SI1     VG       EX    GIA   5169
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL   3470
# 2          0.85  Ideal     H     SI1     EX       EX    GIA   3183
# 3          0.91  Ideal     E     SI1     VG       VG    GIA   4370
# 4          0.83  Ideal     G     SI1     EX       EX    GIA   3171

# %%
diamonds.tail(5)
# Out:
#       Carat Weight              Cut Color Clarity Polish Symmetry Report  \
# 5995          1.03            Ideal     D     SI1     EX       EX    GIA
# 5996          1.00        Very Good     D     SI1     VG       VG    GIA
# 5997          1.02            Ideal     D     SI1     EX       EX    GIA
# 5998          1.27  Signature-Ideal     G     VS1     EX       EX    GIA
# 5999          2.19            Ideal     E     VS1     EX       EX    GIA
#
#       Price
# 5995   6250
# 5996   5328
# 5997   6157
# 5998  11206
# 5999  30507

# %%
diamonds.shape
# Out:
# (6000, 8)

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Carat Weight  6000 non-null   float64
#  1   Cut           6000 non-null   object
#  2   Color         6000 non-null   object
#  3   Clarity       6000 non-null   object
#  4   Polish        6000 non-null   object
#  5   Symmetry      6000 non-null   object
#  6   Report        6000 non-null   object
#  7   Price         6000 non-null   int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 375.1+ KB

# %%
diamonds.describe()
# Out:
#        Carat Weight          Price
# count   6000.000000    6000.000000
# mean       1.334520   11791.579333
# std        0.475696   10184.350051
# min        0.750000    2184.000000
# 25%        1.000000    5150.500000
# 50%        1.130000    7857.000000
# 75%        1.590000   15036.500000
# max        2.910000  101561.000000

# %%
diamonds.keys()
# Out:
# Index(['Carat Weight', 'Cut', 'Color', 'Clarity', 'Polish', 'Symmetry',
#        'Report', 'Price'],
#       dtype='object')

# %% [markdown]
# # Print the total number of entries in the dataset.

# %%
total_entries = len(diamonds)

# %%
print("Total number of entries in the dataset:", total_entries)
# Out:
# Total number of entries in the dataset: 6000

# %% [markdown]
# # Plot the distribution of diamond prices.

# %%
diamond_prices = diamonds['Price']

# %%
plt.figure(figsize=(10, 6))
plt.hist(diamond_prices, bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Diamond Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# # Calculate the average price for each cut and color.

# %%
average_price = diamonds.groupby(['Cut', 'Color'])['Price'].mean()

print("Average price for each cut and color:")
print(average_price)
# Out:
# Average price for each cut and color:
# Cut              Color
# Fair             D         6058.250000
#                  E         5370.625000
#                  F         6063.625000
#                  G         7345.523810
#                  H         5908.500000
#                  I         4573.187500
# Good             D        10058.716216
#                  E         8969.545455
#                  F         9274.007519
#                  G         9988.614865
#                  H         9535.132812
#                  I         8174.113043
# Ideal            D        18461.953571
#                  E        12647.107914
#                  F        14729.426997
#                  G        13570.310145
#                  H        11527.700873
#                  I         9459.588378
# Signature-Ideal  D        19823.100000
#                  E        11261.914286
#                  F        13247.947368
#                  G        10248.296875
#                  H         9112.688889
#                  I         8823.463415
# Very Good        D        13218.826415
#                  E        12101.910217
#                  F        12413.905495
#                  G        12354.013841
#                  H        10056.106132
#                  I         8930.031332
# Name: Price, dtype: float64

# %% [markdown]
# # Print the names of diamonds with the highest and lowest prices

# %%
diamond_max_price = diamonds.loc[diamonds['Price'].idxmax(), 'Price']
diamond_min_price = diamonds.loc[diamonds['Price'].idxmin(), 'Price']

print("Price of the diamond with the highest price:", diamond_max_price)
print("Price of the diamond with the lowest price:", diamond_min_price)
# Out:
# Price of the diamond with the highest price: 101561
# Price of the diamond with the lowest price: 2184

# %% [markdown]
# # Plot the average price by cut and color.

# %%
averageprice_by_cut_color = diamonds.groupby(['Cut', 'Color'])['Price'].mean().unstack()

# %%
averageprice_by_cut_color.plot(kind='bar', figsize=(12, 6), width=0.8)
plt.title('Average Price by Cut and Color')
plt.xlabel('Cut')
plt.ylabel('Average Price')
plt.xticks(rotation=360)
plt.legend(title='Color')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Calculate the correlation between diamond carat weight and price.

# %%
correlation = diamonds['Carat Weight'].corr(diamonds['Price'])

# %%
correlation
# Out:
# 0.8585621341250125

# %% [markdown]
# # Plot the distribution of diamond carat weights.

# %%
carat_weights = diamonds['Carat Weight']


plt.figure(figsize=(10, 6))
plt.hist(carat_weights, bins=30, color='yellow', edgecolor='black')
plt.title('Distribution of Diamond Carat Weights')
plt.xlabel('Carat Weight')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# # Print the names of diamonds with the highest and lowest carat weights

# %% [markdown]
# *************Name of Diamonds column are not present in given dataset*****************

# %%
max_carat = diamonds.loc[diamonds['Carat Weight'].idxmax(), 'Price']
min_carat = diamonds.loc[diamonds['Carat Weight'].idxmin(), 'Price']

print("price of the diamond with the highest carat weight:", max_carat)
print("price of the diamond with the lowest carat weight:", min_carat)
# Out:
# price of the diamond with the highest carat weight: 27277
# price of the diamond with the lowest carat weight: 2734

# %% [markdown]
# # Plot the distribution of diamond clarity levels.

# %%
clarity_levels = diamonds['Clarity']


plt.figure(figsize=(10, 6))
clarity_levels.value_counts().plot(kind='bar', color='orange', edgecolor='black')
plt.title('Distribution of Diamond Clarity Levels')
plt.xlabel('Clarity')
plt.ylabel('Frequency')
plt.xticks(rotation=360)
plt.grid(axis='y', alpha=1)

plt.show()

# %% [markdown]
# # Calculate the average price by clarity level.

# %%
average_clarity = diamonds.groupby('Clarity')['Price'].mean()

print("Average price by clarity level:")
print(average_clarity)
# Out:
# Average price by clarity level:
# Clarity
# FL      63776.000000
# IF      22105.844749
# SI1      8018.864012
# VS1     13694.113255
# VS2     11809.053333
# VVS1    16845.680702
# VVS2    14142.177177
# Name: Price, dtype: float64

# %% [markdown]
# # Print the names of diamonds with the highest and lowest price-per-carat

# %% [markdown]
# *****Name of Diamonds column are not present in given dataset*****

# %%
diamonds['price_per_carat'] = diamonds['Price'] / diamonds['Carat Weight']
highest_ppc_diamond = diamonds.loc[diamonds['price_per_carat'].idxmax(), 'Price']
lowest_ppc_diamond = diamonds.loc[diamonds['price_per_carat'].idxmin(), 'Price']

# %%
print("Price of the diamond with the highest price-per-carat:", highest_ppc_diamond)
print("Price of the diamond with the lowest price-per-carat:", lowest_ppc_diamond)
# Out:
# Price of the diamond with the highest price-per-carat: 81399
# Price of the diamond with the lowest price-per-carat: 2184

# %% [markdown]
# # Plot the distribution of diamond prices by clarity level.

# %%
plt.figure(figsize=(10, 6))
diamonds.boxplot(column='Price', by='Clarity', figsize=(10,6))
plt.title('Distribution of Diamond Prices by Clarity Level')
plt.xlabel('Clarity')
plt.ylabel('Price')
plt.xticks(rotation=360)
plt.show()

# %% [markdown]
# # Calculate the median price for each cut and color.

# %%
median_price = diamonds.groupby(['Cut', 'Color'])['Price'].median()

print("Median price for each cut and color:")
print(median_price)
# Out:
# Median price for each cut and color:
# Cut              Color
# Fair             D         5040.0
#                  E         4908.5
#                  F         4628.0
#                  G         4646.0
#                  H         4358.0
#                  I         3801.0
# Good             D         5763.0
#                  E         5981.5
#                  F         6037.0
#                  G         5954.5
#                  H         5453.5
#                  I         5600.0
# Ideal            D        10338.0
#                  E         8276.5
#                  F        10360.0
#                  G         9510.5
#                  H         8014.0
#                  I         6817.0
# Signature-Ideal  D        11712.5
#                  E        11014.0
#                  F        10433.0
#                  G         8529.0
#                  H         7788.0
#                  I         6980.0
# Very Good        D         6682.0
#                  E         6703.0
#                  F         8330.0
#                  G         8249.0
#                  H         6564.0
#                  I         6684.0
# Name: Price, dtype: float64

# %% [markdown]
# # Print the names of diamonds with the highest and lowest price-per-carat for each clarity level.

# %%
diamonds['price_per_carat'] = diamonds['Price'] / diamonds['Carat Weight']


grouped_data = diamonds.groupby('Clarity')


for clarity, group in grouped_data:
    highest_ppc_diamond = group.loc[group['price_per_carat'].idxmax(), 'Price']
    lowest_ppc_diamond = group.loc[group['price_per_carat'].idxmin(), 'Price']
    print(f"For clarity level {clarity}:")
    print("Price of the diamond with the highest price-per-carat:", highest_ppc_diamond)
    print("Price of the diamond with the lowest price-per-carat:", lowest_ppc_diamond)
    print()
# Out:
# For clarity level FL:
# Price of the diamond with the highest price-per-carat: 81399
# Price of the diamond with the lowest price-per-carat: 33868
#
# For clarity level IF:
# Price of the diamond with the highest price-per-carat: 101561
# Price of the diamond with the lowest price-per-carat: 3437
#
# For clarity level SI1:
# Price of the diamond with the highest price-per-carat: 33928
# Price of the diamond with the lowest price-per-carat: 2241
#
# For clarity level VS1:
# Price of the diamond with the highest price-per-carat: 66554
# Price of the diamond with the lowest price-per-carat: 2184
#
# For clarity level VS2:
# Price of the diamond with the highest price-per-carat: 32582
# Price of the diamond with the lowest price-per-carat: 2444
#
# For clarity level VVS1:
# Price of the diamond with the highest price-per-carat: 75630
# Price of the diamond with the lowest price-per-carat: 3191
#
# For clarity level VVS2:
# Price of the diamond with the highest price-per-carat: 77033
# Price of the diamond with the lowest price-per-carat: 2589

# %% [markdown]
# # Plot the average price by cut and clarity

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=diamonds['Cut'], y=diamonds['Price'], hue=diamonds['Clarity'], estimator=sum)
plt.title('Average Price by Cut and Clarity')
plt.xlabel('Cut')
plt.show()
