# %%
# programmer  Omkar Rahane
#Roll no: 28
#Class :TE Div: B

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
x = np.array ([12,23,34,45,49,56,61,68,71,78])
y = np.array ([23,31,38,43,49,56,65,71,79,85])
z = np.array ([98,89,86,76,71,68,61,54,49,34])

# %% [markdown]
# LINE PLOT

# %%
plt.plot(x,y);

# %%
plt.title('line plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.plot(x, y, marker='o',color='blue',mfc='r',ls='--',ms=7);
plt.grid()

# %%
plt.title('line plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.plot(x, y, marker='*',color='magenta',mfc='r',ls='--',ms=7);
plt.grid()
#marker => <,>,^,o,*,H

# %%
plt.title('line plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.plot(x, y, marker='*',color='magenta',mfc='r',ls='--',ms=7);

plt.plot(x, z, marker='H',color='cyan',mfc='r',ls='--',ms=7);

plt.grid()

#marker => <,>,^,o,*,H

# %% [markdown]
# ##SUBPLOt

# %%
plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
plt.title('line plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.plot(x, y, marker='o',color='blue',mfc='r',ls='--',ms=7);
plt.grid()

plt.subplot(2,2,2)
plt.title('line plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.plot(x, y, marker='*',color='orange',mfc='r',ls='--',ms=7);
plt.grid()

# %%
#BAR GRAPH#

# %%
students =[56,65,46,51,61,20]

courses = ['Java','Python','R','Kotlin','Dart','jadu']

plt.plot(x, y, marker='*',color='orange',mfc='r',ls='--',ms=7);

# %%
plt.bar(courses,students);

# %%
plt.title('Bar PLot')
plt.xlabel('Courses')
plt.ylabel('NO .of students')
plt.bar(courses ,students ,color ='orange',
       edgecolor ='red',
       width = 0.6,
       linewidth = 3,
       alpha = 0.7 );

# %% [markdown]
# ###SCATTER PLOT

# %%
plt.scatter(x,y,marker = '*')
plt.grid()

# %% [markdown]
# #PIE CHART

# %%
plt.title('Pie Chart')
plt.pie(students ,labels =courses,autopct ='%2f%%',
       shadow =True,radius =1.2,labeldistance =1.2,
       colors=['red','blue','green','cyan','magenta','purple'],
       startangle = 30,
       explode = [0,0,0,0.2,0.1,0]);

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title('Line Plot')
plt.xlabel('First value')
plt.ylabel('Second value')
plt.plot(x,y,marker = '*',color='blue',mfc='r',ls='--',ms = 7);


plt.subplot(2,2,2)
plt.title('Bar Graph')
plt.xlabel('courses')
plt.ylabel('No. of students')
plt.bar(courses,students , color= 'pink',edgecolor='black',width=0.6,linewidth=3,alpha=0.7);

plt.subplot(2,2,3)
plt.title('Pie Chart')
plt.pie(students,labels=courses,autopct='%.2f%%',shadow=True, radius=1,labeldistance=1.1,
        colors=['red','yellow','green','pink','black'],startangle=30);

plt.subplot(2,2,4)
plt.title('Scatter Plot')
plt.xlabel('First value')
plt.ylabel('Second value')
plt.scatter(x,y,marker='*')
plt.grid()

plt.savefig('My Plot')

# %% [markdown]
# # Box Plot

# %%
marks=[67,63,70,71,72,56,51,21,95]

# %%
plt.boxplot(marks);

# %%
q3=np.percentile(marks,75)
q1=np.percentile(marks,25)
q3,q1
# Out:
# (71.0, 56.0)

# %%
iqr = q3-q1
iqr# interquartile range
# Out:
# 15.0

# %%
#Quartile deviation = (Q3-Q1)/2

#lowerbound & upperbound
lb=q1-1.5*iqr
ub=q3+1.5*iqr
lb,ub
# Out:
# (33.5, 93.5)

# %%
x=pd.read_csv('student.csv')
x
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
plt.xlabel('First Value')
plt.ylabel('Second Value')

plt.bar(x['marks'],x['roll'],color=['red','blue','green','skyblue','pink','yellow','cyan','teal','orange','purple'],edgecolor='black',linewidth=3);

# %%
plt.xlabel('First Value')
plt.ylabel('Second Value')

plt.barh(x['marks'],x['roll'],color=['red','blue','green','skyblue','pink','yellow','cyan','teal','orange','purple'],edgecolor='black',linewidth=3);

# %%
plt.style.available #avail styles supported
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-pastel')

plt.xlabel('Rollnum')
plt.ylabel('Marks')
plt.bar(x['marks'],x['roll']);

# %%
plt.style.use('seaborn-v0_8-pastel')
plt.xlabel('Rollnum')
plt.ylabel('Marks')
plt.bar(x['marks'],x['roll']);

# %%
#SEABORN

tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib as mpp
mpp.rcParams.update(mpp.rcParamsDefault)

# %%
sns.jointplot(x='tip',y='total_bill',data=tips,hue='time')
plt.show()

# %%
#histogram=freq distribution
plt.xlabel('tip amt')
plt.ylabel('freq')
sns.histplot(tips['tip'],kde=True) #kde is freq distribution curve
plt.show()

# %%
#histogram=freq distribution
plt.xlabel('Day')
plt.ylabel('tip')
#sns.histplot(tips['tip'],kde=True)
sns.boxenplot(x='day',y='tip',data=tips)
plt.show()

#The boxen plot or letter value plot is similar to a box plot but provides more information about the shape of the distribution, particularly in the tails

# %%
sns.pairplot(tips,hue='smoker')
plt.show()
#pairplot is similar to jointplot but
#1) scatter graph is generated for all the numeric values plkresent in the dataset
#2)diagonal graphs are the histogram
